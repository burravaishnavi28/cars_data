# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# setting dimensions for plot
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
# reading csv file
cars_data=pd.read_csv(r"C:\Users\vaish\Downloads\cars_sampled.csv")

# %%
# creating a copy
cars= cars_data.copy()
cars
# Out:
#             dateCrawled                                               name  \
# 0      30/03/2016 13:51                                       Zu_verkaufen
# 1         7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2         1/4/2016 0:57                                  Volkswagen_Touran
# 3      19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4      16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# ...                 ...                                                ...
# 49996    3/4/2016 15:48                               Suche_VW_T5_Multivan
# 49997  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 49998  14/03/2016 18:51  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 49999  15/03/2016 18:06        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 50000   22/03/2016 9:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType  price   abtest    vehicleType  \
# ...

# %%
# summarizing data
cars.describe()
pd.set_option('display.float_format',lambda x: '%.3f' %x)
cars.describe()
# Out:
#              price  yearOfRegistration   powerPS  kilometer  \
# count    50001.000           50001.000 50001.000  50001.000
# mean      6559.865            2005.544   116.496 125613.688
# std      85818.470             122.992   230.568  40205.234
# min          0.000            1000.000     0.000   5000.000
# 25%       1150.000            1999.000    69.000 125000.000
# 50%       2950.000            2003.000   105.000 150000.000
# 75%       7190.000            2008.000   150.000 150000.000
# max   12345678.000            9999.000 19312.000 150000.000
#
#        monthOfRegistration  postalCode
# count            50001.000   50001.000
# mean                 5.744   50775.217
# std                  3.711   25743.702
# min                  0.000    1067.000
# 25%                  3.000   30559.000
# 50%                  6.000   49504.000
# 75%                  9.000   71404.000
# max                 12.000   99998.000

# %%
# to display maximum set of columns
pd.set_option('display.max_columns',500)
cars.describe()
# Out:
#              price  yearOfRegistration   powerPS  kilometer  \
# count    50001.000           50001.000 50001.000  50001.000
# mean      6559.865            2005.544   116.496 125613.688
# std      85818.470             122.992   230.568  40205.234
# min          0.000            1000.000     0.000   5000.000
# 25%       1150.000            1999.000    69.000 125000.000
# 50%       2950.000            2003.000   105.000 150000.000
# 75%       7190.000            2008.000   150.000 150000.000
# max   12345678.000            9999.000 19312.000 150000.000
#
#        monthOfRegistration  postalCode
# count            50001.000   50001.000
# mean                 5.744   50775.217
# std                  3.711   25743.702
# min                  0.000    1067.000
# 25%                  3.000   30559.000
# 50%                  6.000   49504.000
# 75%                  9.000   71404.000
# max                 12.000   99998.000

# %%
# to display max set of columns
# dropping unwanted columns
col=['name','dateCrawled','dateCreated','postalCode','lastSeen']
cars=cars.drop(columns=col,axis=1)

# %%
cars
# Out:
#            seller offerType  price   abtest    vehicleType  \
# 0         private     offer   4450     test      limousine
# 1         private     offer  13299  control            suv
# 2         private     offer   3200     test            bus
# 3         private     offer   4500  control      small car
# 4         private     offer  18750     test            suv
# ...           ...       ...    ...      ...            ...
# 49996     private   request      0     test            bus
# 49997     private   request  19999  control            NaN
# 49998     private   request      0     test          coupe
# 49999  commercial     offer    100  control  station wagon
# 50000  commercial     offer   1100     test      small car
#
#        yearOfRegistration    gearbox  powerPS        model  kilometer  \
# 0                    2003     manual      150          3er     150000
# 1                    2005     manual      163     xc_reihe     150000
# ...

# %%
# removing duplicate records 
cars.drop_duplicates(keep='first',inplace=True)

# %%
cars
# Out:
#            seller offerType  price   abtest    vehicleType  \
# 0         private     offer   4450     test      limousine
# 1         private     offer  13299  control            suv
# 2         private     offer   3200     test            bus
# 3         private     offer   4500  control      small car
# 4         private     offer  18750     test            suv
# ...           ...       ...    ...      ...            ...
# 49996     private   request      0     test            bus
# 49997     private   request  19999  control            NaN
# 49998     private   request      0     test          coupe
# 49999  commercial     offer    100  control  station wagon
# 50000  commercial     offer   1100     test      small car
#
#        yearOfRegistration    gearbox  powerPS        model  kilometer  \
# 0                    2003     manual      150          3er     150000
# 1                    2005     manual      163     xc_reihe     150000
# ...

# %%
# 470 duplicate records

# %%
# no of missing values in each column
cars.isnull().sum()
# Out:
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            5152
# yearOfRegistration        0
# gearbox                2765
# powerPS                   0
# model                  2730
# kilometer                 0
# monthOfRegistration       0
# fuelType               4467
# brand                     0
# notRepairedDamage      9640
# dtype: int64

# %%
# variable yearsofRegistraion
yearwise_count=cars['yearOfRegistration'].value_counts().sort_index()
#yearwise_count=cars['yearOfRegistration']
#yearwise_count
sum(cars['yearOfRegistration']> 2018)
sum(cars['yearOfRegistration']< 1950)
sns.regplot(x='yearOfRegistration',y="price",scatter=True,fit_reg=False,data=cars)
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
# variable price
price_count=cars['price'].value_counts().sort_index()
sns.distplot(cars['price'])
cars['price'].describe()
sns.boxplot(y=cars['price'])
sum(cars['price']>150000)
sum(cars['price']<100)
# Out:
# C:\Users\vaish\AppData\Local\Temp\ipykernel_16864\459113180.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['price'])
# C:\Users\vaish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 1748

# %%
# variable powerps
price_count=cars['powerPS'].value_counts().sort_index()
sns.distplot(cars['powerPS'])
cars['powerPS'].describe()
sns.boxplot(y=cars['powerPS'])
sns.regplot(x='powerPS',y='price',scatter=True,fit_reg=False,data=cars)
sum(cars['powerPS']>500)
sum(cars['powerPS']<10)
# Out:
# C:\Users\vaish\AppData\Local\Temp\ipykernel_16864\3507561062.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['powerPS'])
# C:\Users\vaish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 5565

# %%
# working range of data
cars=cars[(cars.yearOfRegistration <= 2018)
& (cars.yearOfRegistration >= 1950)
& (cars.price >= 100)
& (cars.price <= 150000)
& (cars.powerPS >= 10)
& (cars.powerPS <= 500)]

# %%
cars
# Out:
#            seller offerType  price   abtest    vehicleType  \
# 0         private     offer   4450     test      limousine
# 1         private     offer  13299  control            suv
# 2         private     offer   3200     test            bus
# 3         private     offer   4500  control      small car
# 4         private     offer  18750     test            suv
# ...           ...       ...    ...      ...            ...
# 49991     private     offer  10900     test      limousine
# 49992     private     offer    790     test      limousine
# 49993     private     offer    830     test      small car
# 49995     private     offer   2290     test  station wagon
# 50000  commercial     offer   1100     test      small car
#
#        yearOfRegistration    gearbox  powerPS     model  kilometer  \
# 0                    2003     manual      150       3er     150000
# 1                    2005     manual      163  xc_reihe     150000
# ...

# %%
#6700 record are dropped

# %%
# combining yearof registration and monthof registration
cars['monthOfRegistration']/=12
# Out:
# C:\Users\vaish\AppData\Local\Temp\ipykernel_16864\1627349096.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['monthOfRegistration']/=12

# %%
cars
# Out:
#            seller offerType  price   abtest    vehicleType  \
# 0         private     offer   4450     test      limousine
# 1         private     offer  13299  control            suv
# 2         private     offer   3200     test            bus
# 3         private     offer   4500  control      small car
# 4         private     offer  18750     test            suv
# ...           ...       ...    ...      ...            ...
# 49991     private     offer  10900     test      limousine
# 49992     private     offer    790     test      limousine
# 49993     private     offer    830     test      small car
# 49995     private     offer   2290     test  station wagon
# 50000  commercial     offer   1100     test      small car
#
#        yearOfRegistration    gearbox  powerPS     model  kilometer  \
# 0                    2003     manual      150       3er     150000
# 1                    2005     manual      163  xc_reihe     150000
# ...

# %%
# creating a new varaible Age by ading yearof registration and monthof registratin
cars['Age']=(2018-cars['yearOfRegistration'])+cars['monthOfRegistration']
cars['Age']=round(cars['Age'],2)
cars['Age'].describe()
# Out:
# C:\Users\vaish\AppData\Local\Temp\ipykernel_16864\3406638026.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['Age']=(2018-cars['yearOfRegistration'])+cars['monthOfRegistration']
# C:\Users\vaish\AppData\Local\Temp\ipykernel_16864\3406638026.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['Age']=round(cars['Age'],2)
# count   42772.000
# mean       14.873
# std         7.093
# min         0.000
# 25%        10.330
# 50%        14.830
# 75%        19.170
# ...

# %%
cars
# Out:
#            seller offerType  price   abtest    vehicleType  \
# 0         private     offer   4450     test      limousine
# 1         private     offer  13299  control            suv
# 2         private     offer   3200     test            bus
# 3         private     offer   4500  control      small car
# 4         private     offer  18750     test            suv
# ...           ...       ...    ...      ...            ...
# 49991     private     offer  10900     test      limousine
# 49992     private     offer    790     test      limousine
# 49993     private     offer    830     test      small car
# 49995     private     offer   2290     test  station wagon
# 50000  commercial     offer   1100     test      small car
#
#        yearOfRegistration    gearbox  powerPS     model  kilometer  \
# 0                    2003     manual      150       3er     150000
# 1                    2005     manual      163  xc_reihe     150000
# ...

# %%
# dropping yearof registration and monthofregistration
cars=cars.drop(columns=['yearOfRegistration','monthOfRegistration'],axis=1)

# %%
cars
# Out:
#            seller offerType  price   abtest    vehicleType    gearbox  \
# 0         private     offer   4450     test      limousine     manual
# 1         private     offer  13299  control            suv     manual
# 2         private     offer   3200     test            bus     manual
# 3         private     offer   4500  control      small car     manual
# 4         private     offer  18750     test            suv  automatic
# ...           ...       ...    ...      ...            ...        ...
# 49991     private     offer  10900     test      limousine     manual
# 49992     private     offer    790     test      limousine     manual
# 49993     private     offer    830     test      small car     manual
# 49995     private     offer   2290     test  station wagon     manual
# 50000  commercial     offer   1100     test      small car     manual
#
#        powerPS     model  kilometer fuelType       brand notRepairedDamage  \
# ...

# %%
# visualizing parameters
#Age
sns.displot(cars['Age'])
#sns.boxplot(y=vars['Age'])
# Out:
# C:\Users\vaish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(y=cars['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
# price
sns.displot(cars['price'])
# Out:
# C:\Users\vaish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(y=cars['price'])
# Out:
# <Axes: ylabel='price'>

# %%
# powerps
sns.displot(cars['powerPS'])
# Out:
# C:\Users\vaish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(y=cars['powerPS'])
# Out:
# <Axes: ylabel='powerPS'>

# %%
# visualizing parameters after narrowing working range 
# age vs price
sns.regplot(x='Age',y='price',scatter=True,fit_reg=False,data=cars)
# Out:
# <Axes: xlabel='Age', ylabel='price'>

# %%
# with increse in age,price decresed

# %%
# powerps vs price
sns.regplot(x='powerPS',y='price',scatter=True,fit_reg=False,data=cars)
# Out:
# <Axes: xlabel='powerPS', ylabel='price'>

# %%
# variable seller 
cars['seller'].value_counts()
pd.crosstab(cars['seller'],columns='count',normalize=True)
sns.countplot(x='seller',data=cars)
# Out:
# <Axes: xlabel='seller', ylabel='count'>

# %%
# Fewer cars have ' commercial => insignificant

# %%
# varaible abtest
cars['abtest'].value_counts()
pd.crosstab(cars['abtest'],columns='count',normalize=True)
sns.countplot(x='abtest',data=cars)
# Out:
# <Axes: xlabel='abtest', ylabel='count'>

# %%
# equally distributed
sns.boxplot(x='abtest',y='price',data=cars)
# Out:
# <Axes: xlabel='abtest', ylabel='price'>

# %%
# varaible vehivle type
cars['vehicleType'].value_counts()
pd.crosstab(cars['vehicleType'],columns='count',normalize=True)
sns.countplot(x='vehicleType',data=cars)
# Out:
# <Axes: xlabel='vehicleType', ylabel='count'>

# %%
sns.boxplot(x='vehicleType',y='price',data=cars)
# Out:
# <Axes: xlabel='vehicleType', ylabel='price'>

# %%
# varaible garebox
cars['gearbox'].value_counts()
pd.crosstab(cars['gearbox'],columns='count',normalize=True)
sns.countplot(x='gearbox',data=cars)
# Out:
# <Axes: xlabel='gearbox', ylabel='count'>

# %%
sns.boxplot(x='gearbox',y='price',data=cars)
# Out:
# <Axes: xlabel='gearbox', ylabel='price'>

# %%
# varaible model
cars['model'].value_counts()
pd.crosstab(cars['model'],columns='count',normalize=True)
sns.countplot(x='model',data=cars)
# Out:
# <Axes: xlabel='model', ylabel='count'>

# %%
sns.boxplot(x='model',y='price',data=cars)
# Out:
# <Axes: xlabel='model', ylabel='price'>

# %%
# cars are distributed over many models

# %%
# varaible kilometers
cars['kilometer'].value_counts().sort_index()
pd.crosstab(cars['kilometer'],columns='count',normalize=True)
sns.boxplot(x='kilometer',y='price',data=cars)
cars['kilometer'].describe()
sns.displot(cars['kilometer'],bins=8,kde=False)
sns.regplot(x='kilometer',y='price',scatter=True,fit_reg=False,data=cars)
#sns.countplot(x='model',data=cars)
# Out:
# C:\Users\vaish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='kilometer', ylabel='price'>

# %%
# varaible fuel type
cars['fuelType'].value_counts()
pd.crosstab(cars['fuelType'],columns='count',normalize=True)
sns.countplot(x='fuelType',data=cars)
sns.boxplot(x='fuelType',y='price',data=cars)
# Out:
# <Axes: xlabel='fuelType', ylabel='price'>

# %%
# varaible brand
cars['brand'].value_counts()
pd.crosstab(cars['brand'],columns='count',normalize=True)
sns.countplot(x='brand',data=cars)
sns.boxplot(x='brand',y='price',data=cars)
# Out:
# <Axes: xlabel='brand', ylabel='price'>

# %%
# variable notrepairdDamage
cars['notRepairedDamage'].value_counts()
pd.crosstab(cars['notRepairedDamage'],columns='count',normalize=True)
sns.countplot(x='notRepairedDamage',data=cars)
sns.boxplot(x='notRepairedDamage',y='price',data=cars)
# Out:
# <Axes: xlabel='notRepairedDamage', ylabel='price'>

# %%
# yes- car is damged but not rectified
#no-car is damged but has been  rectified

# %%
# Removing insignificant columns(varaibles)
col=['seller','offerType','abtest']
cars=cars.drop(columns=col,axis=1)
cars_copy=cars.copy()

# %%
cars
# Out:
#        price    vehicleType    gearbox  powerPS     model  kilometer fuelType  \
# 0       4450      limousine     manual      150       3er     150000   diesel
# 1      13299            suv     manual      163  xc_reihe     150000   diesel
# 2       3200            bus     manual      101    touran     150000   diesel
# 3       4500      small car     manual       86     ibiza      60000   petrol
# 4      18750            suv  automatic      185  xc_reihe     150000   diesel
# ...      ...            ...        ...      ...       ...        ...      ...
# 49991  10900      limousine     manual      231   x_reihe     150000   petrol
# 49992    790      limousine     manual       82     astra     150000   diesel
# 49993    830      small car     manual       60      clio     125000   petrol
# 49995   2290  station wagon     manual      101     astra     150000   petrol
# 50000   1100      small car     manual       38     matiz     150000   petrol
#
# ...

# %%
# correlation
cars_select1=cars.select_dtypes(exclude=[object])
correlation=cars_select1.corr()
round(correlation,3)
cars_select1.corr().loc[:,'price'].abs().sort_values(ascending=False)[1:]
# Out:
# powerPS     0.575
# kilometer   0.440
# Age         0.336
# Name: price, dtype: float64

# %%
# omitting missing values
cars_omit=cars.dropna(axis=0)
# converting catergorical variables to dummy varibles 
cars_omit=pd.get_dummies(cars_omit,drop_first=True)

# %%
cars_omit
# Out:
#        price  powerPS  kilometer    Age  vehicleType_cabrio  \
# 1      13299      163     150000 13.500               False
# 3       4500       86      60000 13.000               False
# 4      18750      185     150000 10.920               False
# 5        988       90     150000 23.170               False
# 7       1399      136     150000 21.920               False
# ...      ...      ...        ...    ...                 ...
# 49991  10900      231     150000 14.670               False
# 49992    790       82     150000 20.750               False
# 49993    830       60     125000 19.670               False
# 49995   2290      101     150000 17.250               False
# 50000   1100       38     150000 12.830               False
#
#        vehicleType_coupe  vehicleType_limousine  vehicleType_others  \
# 1                  False                  False               False
# 3                  False                  False               False
# ...

# %%
# importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# model building with omitted data

# %%
# seperating input and outputfeatures
x1 = cars_omit.drop(['price'],axis='columns',inplace=False)
y1 = cars_omit['price']

# %%
# plotting the varaibles price
prices = pd.DataFrame({'1.Before':y1,'2.After':np.log(y1)})
prices.hist()
# Out:
# array([[<Axes: title={'center': '1.Before'}>,
#         <Axes: title={'center': '2.After'}>]], dtype=object)

# %%
# transforming price as a logarithmic value
y1=np.log(y1)

# %%
y1
# Out:
# 1       9.495
# 3       8.412
# 4       9.839
# 5       6.896
# 7       7.244
#          ...
# 49991   9.297
# 49992   6.672
# 49993   6.721
# 49995   7.736
# 50000   7.003
# Name: price, Length: 32884, dtype: float64

# %%
# splitting data into test and train
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size=3,random_state=3)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (32881, 300) (3, 300) (32881,) (3,)

# %%
# baseline model for omitted data
# finding the mean for test data value
base_pred = np.mean(y_test)
print(base_pred)
# Out:
# 9.045279886269514

# %%
# repeating same value till length of test data
base_pred=np.repeat(base_pred,len(y_test))

# %%
# finding the RMSE
base_root_mean_square_error=np.sqrt(mean_squared_error(y_test,base_pred))
print(base_root_mean_square_error)
# Out:
# 0.4496136184426762

# %%
# linear regression with omitted data
# setting intercept as true
lgr=LinearRegression(fit_intercept=True)

# %%
lgr
# Out:
# LinearRegression()

# %%
# model
model_lin1=lgr.fit(x_train,y_train)

# %%
model_lin1
# Out:
# LinearRegression()

# %%
# predicting model on test set
cars_predections_lin1=lgr.predict(x_test)
cars_predections_lin1
# Out:
# array([8.44331123, 9.77907684, 8.98686752])

# %%
# computing MSE and RMSE
lin_mse1=mean_squared_error(y_test,cars_predections_lin1)
lin_rmse1=np.sqrt(lin_mse1)
print(lin_rmse1)
# Out:
# 0.2518820155318197

# %%
# R squared value
r2_lin_test1=model_lin1.score(x_test,y_test)
r2_lin_train1=model_lin1.score(x_train,y_train)

# %%
# regression diagnostics-Residual plot analysis
residuals1=y_test-cars_predections_lin1
sns.regplot(x=cars_predections_lin1,y=residuals1,scatter=True,fit_reg=False)
residuals1.describe()
# Out:
# count    3.000
# mean    -0.024
# std      0.307
# min     -0.288
# 25%     -0.193
# 50%     -0.099
# 75%      0.107
# max      0.313
# Name: price, dtype: float64

# %%
#Random forset with omitted data
# model parameter
rf= RandomForestRegressor(n_estimators = 100,max_features='auto',max_depth=100,min_samples_split=10,min_samples_leaf=4,random_state=1)

# %%
rf
# Out:
# RandomForestRegressor(max_depth=100, max_features='auto', min_samples_leaf=4,
#                       min_samples_split=10, random_state=1)

# %%
# model
model_rf1=rf.fit(x_train,y_train)
# Out:
# C:\Users\vaish\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(

# %%
# predicting model on tset set
cars_predictions_rf1=rf.predict(x_test)

# %%
cars_predictions_rf1
# Out:
# array([8.67261691, 9.53854321, 8.35948923])

# %%
# compute MSF and RMSF
rf_mse1=mean_squared_error(y_test,cars_predictions_rf1)
rf_rmse1=np.sqrt(rf_mse1)
print(rf_rmse1)
# Out:
# 0.21800733479837664

# %%
# R equared value
r2_rf_test1=model_rf1.score(x_test,y_test)
r2_rf_train1=model_rf1.score(x_train,y_train)
print(r2_rf_test1,r2_rf_train1)
# Out:
# 0.7648942251423867 0.9201027653454961

# %%
# model testing with inputed data
cars_imputed = cars.apply(lambda x:x.fillna(x.median())\
                         if x.dtype=='float' else \
                         x.fillna(x.value_counts().index[0]))
cars_imputed.isnull().sum()
# Out:
# price                0
# vehicleType          0
# gearbox              0
# powerPS              0
# model                0
# kilometer            0
# fuelType             0
# brand                0
# notRepairedDamage    0
# Age                  0
# dtype: int64

# %%
# coverting carogirical varaibles to dummy values
cars_imputed=pd.get_dummies(cars_imputed,drop_first=True)

# %%
cars_imputed
# Out:
#        price  powerPS  kilometer    Age  vehicleType_cabrio  \
# 0       4450      150     150000 15.250               False
# 1      13299      163     150000 13.500               False
# 2       3200      101     150000 15.920               False
# 3       4500       86      60000 13.000               False
# 4      18750      185     150000 10.920               False
# ...      ...      ...        ...    ...                 ...
# 49991  10900      231     150000 14.670               False
# 49992    790       82     150000 20.750               False
# 49993    830       60     125000 19.670               False
# 49995   2290      101     150000 17.250               False
# 50000   1100       38     150000 12.830               False
#
#        vehicleType_coupe  vehicleType_limousine  vehicleType_others  \
# 0                  False                   True               False
# 1                  False                  False               False
# ...

# %%
# model building with imputed data
# seperate input and output feature
x2=cars_imputed.drop(['price'],axis='columns',inplace=False)
y2=cars_imputed['price']

# %%
x2
# Out:
#        powerPS  kilometer    Age  vehicleType_cabrio  vehicleType_coupe  \
# 0          150     150000 15.250               False              False
# 1          163     150000 13.500               False              False
# 2          101     150000 15.920               False              False
# 3           86      60000 13.000               False              False
# 4          185     150000 10.920               False              False
# ...        ...        ...    ...                 ...                ...
# 49991      231     150000 14.670               False              False
# 49992       82     150000 20.750               False              False
# 49993       60     125000 19.670               False              False
# 49995      101     150000 17.250               False              False
# 50000       38     150000 12.830               False              False
#
#        vehicleType_limousine  vehicleType_others  vehicleType_small car  \
# ...

# %%
y2
# Out:
# 0         4450
# 1        13299
# 2         3200
# 3         4500
# 4        18750
#          ...
# 49991    10900
# 49992      790
# 49993      830
# 49995     2290
# 50000     1100
# Name: price, Length: 42772, dtype: int64

# %%
# plotting the varaible price
prices=pd.DataFrame({'1.Before':y2,'2.After':np.log(y2)})
prices.hist()
# Out:
# array([[<Axes: title={'center': '1.Before'}>,
#         <Axes: title={'center': '2.After'}>]], dtype=object)

# %%
# Tranforming price as a logrithimic value
y2=np.log(y2)

# %%
y2
# Out:
# 0       8.401
# 1       9.495
# 2       8.071
# 3       8.412
# 4       9.839
#          ...
# 49991   9.297
# 49992   6.672
# 49993   6.721
# 49995   7.736
# 50000   7.003
# Name: price, Length: 42772, dtype: float64

# %%
# splitting te data for test and train
x_train1,x_test1,y_train1,y_test1=train_test_split(x2,y2,test_size=0.3,random_state=3)
print(x_train1.shape,x_test1.shape,y_train1.shape,y_test1.shape)
# Out:
# (29940, 303) (12832, 303) (29940,) (12832,)

# %%
# baseline model for imputed data
# finding the mean test data value
base_pred=np.mean(y_test1)
print(base_pred)
# Out:
# 8.068391740519065

# %%
# repeating same value till the length of the test data
base_pred=np.repeat(base_pred,len(y_test))

# %%
base_pred
# Out:
# array([8.06839174, 8.06839174, 8.06839174])

# %%
# finding the RMSE
base_root_mean_square_error_imputed=np.sqrt(mean_squared_error(y_test,base_pred))
print(base_root_mean_square_error_imputed)
# Out:
# 1.075389629481737

# %%
# linear regression with imputed data
# setting intercept as trure
lgr2= LinearRegression(fit_intercept=True)

# %%
#model
model_lin2=lgr2.fit(x_train1,y_train1)
model_lin2
# Out:
# LinearRegression()

# %%
# predicting model on test set
cars_predections_lin2=lgr2.predict(x_test1)
cars_predections_lin2
# Out:
# array([8.94230591, 8.37209977, 9.51036542, ..., 8.2115615 , 7.76484305,
#        8.6818465 ])

# %%
# compute MSE and RMSE
lin_mse2=mean_squared_error(y_test1,cars_predections_lin2)
lin_rmse2=np.sqrt(lin_mse2)
print(lin_rmse2)
# Out:
# 0.6483956449231294

# %%
# r squared value
r2_lin_test2=model_lin2.score(x_test1,y_test1)
r2_lin_train2=model_lin2.score(x_train1,y_train1)
print(r2_lin_test2,r2_lin_train2)
# Out:
# 0.7023339008631186 0.7071658736894363

# %%
# Random forest with imputed data
# model parameters
rf2=RandomForestRegressor(n_estimators = 100,max_features='auto',max_depth = 100,min_samples_split=10,min_samples_leaf=4,random_state=1)
rf2
# Out:
# RandomForestRegressor(max_depth=100, max_features='auto', min_samples_leaf=4,
#                       min_samples_split=10, random_state=1)

# %%
# model
model_rf2=rf2.fit(x_train1,y_train1)
# Out:
# C:\Users\vaish\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(

# %%
# predicting model test on test set
cars_predections_rf2=lgr2.predict(x_test1)
cars_predections_rf2

# %%
# compute MSE and RMSE
rf_mse2=mean_squared_error(y_test1,cars_predections_rf2)
rf_rmse2=np.sqrt(rf_mse2)
print(rf_rmse2)

# %%
# R swuared value
r2_rf_test2=model_rf2.score(x_test1,y_test1)
r2_rf_train2=model_rf2.score(x_train1,y_train1)
print(r2_rf_test2,r2_rf_train2)

# %%
# out put
print("metrics for models builtfrom data where missing valueswere omitted")
print("R squared value for train from Linear Regression =%s"% r2_lin_train1)
print("R squared value for train from Linear Regression =%s"% r2_lin_test1)
print("R squared value for train from Random Forest =%s"% r2_rf_train1)
print("R squared value for train from Random Forest =%s"% r2_rf_test1)
print("Base RMSE of model built from data where missing valueswere omitted =%s"%base_root_mean_square_error_imputed)
print("RMSE value for test from linear regression =%s"% lin_rmse1)
print("RMSE value for test from Random Forest =%s"% rf_rmse1)
print("\n\n")
print("metrics for models builtfrom data where missing valueswere imputed")
print("R squared value for train from Linear Regression =%s"% r2_lin_train2)
print("R squared value for train from Linear Regression =%s"% r2_lin_test2)
print("R squared value for train from Random Forest =%s"% r2_rf_train2)
print("R squared value for train from Random Forest =%s"% r2_rf_test2)
print("Base RMSE of model built from data where missing valueswere omitted =%s"%base_root_mean_square_error_imputed)
print("RMSE value for test from linear regression =%s"% lin_rmse2)
print("RMSE value for test from Random Forest =%s"% rf_rmse2)
